# %% [markdown]
# Soal 1: Pemahaman Machine Learning
# Jawab/Kerjakan pertanyaan/perintah di bawah ini dengan bahasa kalian sendiri:
#
# Apa itu machine learning? merupakan cabang ilmu kecerdasan buatan (artficial Intelligence/AI) yang mempelajari tentang bagaimana komputer mampu belajar dari data untuk meningkatkan kecerdasannya
#
# Apa itu data feature dan data target?
# data feature adalah input dan data target adalah outpu
#
# Apa Perbedaan Supervised Learning dan Unsupervised Learning?
# supervised learning adalah metode di machine learning yang dimana ia akan menggunakan label untuk pengelompokannya
# unsupervises learning tidak menggunakan label dan di kelompokkan berdasarkan persamaan
#
# Apa Jenis2 yang ada di dalam Supervised Learning? Jelaskan Perbedaannya!
# classification dan regression
# classification : menggunakan class label. contohnya untuk cuaca, apakah ia mendung, hujan, atau cera
# regression : quantity yang continues. contohnya untuk nilai sekumpulan siswa di kelas, ada rentang value yang nilainya continues
#
#
# Apa perbedaan Hyperparameter dan Parameter?
# hyperparameter di definikan di awal
# parameter di hasilkan di akhir
#
# Sebutkan Langkah-langkah dalam mengaplikasikan algoritma apapun dalam machine learning!
# 1. pilih model/algoritma yang digunakan
# 2. pilih hyperparameter ketika membuat objek model
# 3. pisahkan antara data feature dan data target
# 4. perintahkan model untuk mempelajari data dan menggunakan method .fit()
# 5. aplikasikan model ke dalam test data dengan menggunakan method .predict() untuk supervised learning atau .transform() dan .predict() untuk unsupervised learning

# %% [markdown]
# Soal 2: Pemahaman Machine Learning
# Pelajarilah secara garis besar suatu model/algoritma machine learning, kemudian aplikasikan untuk membuat model bagi data (variable x, y) di bawah ini. Kemudian buatlah prediksi terhadap data training dan data baru di interval 20-30.
# Plot data asli, data hasil prediksi terhadap data training, data hasil prediksi terhadap data baru
# Tunjukan beberapa parameter yang dimiliki model yang telah kalian buat

# %%
import matplotlib.pyplot as plt
import numpy as np

rng = np.random.RandomState(42)
x = 20 * rng.rand(50)
y = x**2 + 2 * x + - 1 + rng.randn(50)

# data yang akan di prediksi
x_new = np.arange(20, 30, 0.5)

fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y)
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.show()

# %%
LinearRegression?

# %%
from sklearn.linear_model import LinearRegression


model_lr = LinearRegression (fit_intercept = True)

x_matrix = x [:, np.newaxis]
model_lr.fit(x_matrix,y)

x_new = np.arange(20, 30, 0.5)
x_new = x_new[:, np.newaxis]

y_new = model_lr.predict(x_new)
y_train = model_lr.predict(x_matrix)

fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y, color = 'g', label ='Data Asli')
plt.plot(x,y_train, label = 'Prediksi Terhadap Data Training')
plt.plot(x_new, y_new, label = 'Prediksi Terhadap Data Baru')
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.legend()
plt.show()
